# %%
import requests
import os
from pprint import pprint
import csv
import json
import time

# %% [markdown]
# ### Scrape by certain date range since we can only have 100 pages worth of results (10 articls per page), and sleep for 6 seconds after every page turn, save each page in different json file since not all results have same dictionary key

# %%
apikey = os.getenv('NYTIMES_APIKEY', 'ufJL0jZynKn50qXLjAtOHxARJRhSs4en')

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20040101"  # YYYYMMDD
    end_date='20040401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20040402"  # YYYYMMDD
    end_date='20040801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush1_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20040802"  # YYYYMMDD
    end_date='20050101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush2_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20050102"  # YYYYMMDD
    end_date='20050401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush3_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20050402"  # YYYYMMDD
    end_date='20050801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush4_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20050802"  # YYYYMMDD
    end_date='20060101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush5_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20060102"  # YYYYMMDD
    end_date='20060401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush6_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20060402"  # YYYYMMDD
    end_date='20060801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush7_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20060802"  # YYYYMMDD
    end_date='20070101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush8_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20070102"  # YYYYMMDD
    end_date='20070401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush9_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20070402"  # YYYYMMDD
    end_date='20070801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush10_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20070802"  # YYYYMMDD
    end_date='20080101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush11_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20080102"  # YYYYMMDD
    end_date='20080401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush12_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20080402"  # YYYYMMDD
    end_date='20080801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush13_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20080802"  # YYYYMMDD
    end_date='20090101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush14_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20090102"  # YYYYMMDD
    end_date='20090401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush15_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20090402"  # YYYYMMDD
    end_date='20090801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush16_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-b9b571594a48> in <module>
#      17                 f"&sort={sort}"
#      18     r = requests.get(query_url)
# ---> 19     keys=r.json()['response']['docs'][0].keys()
#      20     file = r.json()['response']['docs']
#      21
#
# IndexError: list index out of range

# %%
#2004-2009, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20090802"  # YYYYMMDD
    end_date='20100101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush17_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20100102"  # YYYYMMDD
    end_date='20110101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush18_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20110102"  # YYYYMMDD
    end_date='20120101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush19_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20120102"  # YYYYMMDD
    end_date='20130101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush20_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20130102"  # YYYYMMDD
    end_date='20140101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush21_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20140102"  # YYYYMMDD
    end_date='20150101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush22_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,91):
    query = "Bush, George W"
    begin_date = "20150102"  # YYYYMMDD
    end_date='20160101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush23_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-e2e3e03b87c9> in <module>
#      17                 f"&sort={sort}"
#      18     r = requests.get(query_url)
# ---> 19     keys=r.json()['response']['docs'][0].keys()
#      20     file = r.json()['response']['docs']
#      21
#
# KeyError: 'response'

# %%
#2010-present yearly 
for i in range(0,91):
    query = "Bush, George W"
    begin_date = "20160102"  # YYYYMMDD
    end_date='20170101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush24_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,91):
    query = "Bush, George W"
    begin_date = "20170102"  # YYYYMMDD
    end_date='20180101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush25_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,91):
    query = "Bush, George W"
    begin_date = "20180102"  # YYYYMMDD
    end_date='20190101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush26_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,91):
    query = "Bush, George W"
    begin_date = "20190102"  # YYYYMMDD
    end_date='20200101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush27_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2010-present yearly 
for i in range(0,91):
    query = "Bush, George W"
    begin_date = "20200102"  # YYYYMMDD
    end_date='20210301'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush28_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2004-2009, every 4 months #2010-present yearly

# %%
# query = "Bush, George W"
# begin_date = "20050802"  # YYYYMMDD
# end_date="20060101"
# filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
#                                         # http://www.lucenetutorial.com/lucene-query-syntax.html
# page = "0"  # <0-100>
# sort = "relevance"  # newest, oldest
# query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
#             f"q={query}" \
#             f"&api-key={apikey}" \
#             f"&begin_date={begin_date}" \
#             f"&end_date={end_date}" \
#             f"&fq={filter_query}" \
#             f"&page={page}" \
#             f"&sort={sort}"
# r = requests.get(query_url)

# pprint(r.json())
