# %%
import requests
import os
from pprint import pprint
import csv
import json
import time

# %% [markdown]
# ### Scrape by certain date range since we can only have 100 pages worth of results (10 articls per page), and sleep for 6 seconds after every page turn, save each page in different json file since not all results have same dictionary key

# %%
apikey = os.getenv('NYTIMES_APIKEY', 'ufJL0jZynKn50qXLjAtOHxARJRhSs4en')

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20000101"  # YYYYMMDD
    end_date='20000401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush29_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20000402"  # YYYYMMDD
    end_date='20000801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush30_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20000802"  # YYYYMMDD
    end_date='20010101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush31_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20010102"  # YYYYMMDD
    end_date='20010401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush32_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20010402"  # YYYYMMDD
    end_date='20010801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush33_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20010802"  # YYYYMMDD
    end_date='20020101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush34_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20020102"  # YYYYMMDD
    end_date='20020401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush35_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20020402"  # YYYYMMDD
    end_date='20020801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush36_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20020802"  # YYYYMMDD
    end_date='20030101'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush37_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20030102"  # YYYYMMDD
    end_date='20030401'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush38_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20030402"  # YYYYMMDD
    end_date='20030801'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush39_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
#2000-2004, every 4 months
for i in range(0,101):
    query = "Bush, George W"
    begin_date = "20030802"  # YYYYMMDD
    end_date='20031231'
    filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
    page = i  # <0-100>
    sort = "relevance"  # newest, oldest
    query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
                f"q={query}" \
                f"&api-key={apikey}" \
                f"&begin_date={begin_date}" \
                f"&end_date={end_date}" \
                f"&fq={filter_query}" \
                f"&page={page}" \
                f"&sort={sort}"
    r = requests.get(query_url)
    keys=r.json()['response']['docs'][0].keys()
    file = r.json()['response']['docs']
        
    name_file="bush40_{num}.json".format(num=i) 
    with open(name_file, 'w') as output_file:
        json.dump(file, output_file)
    time.sleep(6)

# %%
query = "Bush, George W"
begin_date = "20030802"  # YYYYMMDD
end_date='20031231'
filter_query = "\"body:(\"Geoge W. Bush\") AND type_of_material:(\"Article\")\""  
                                            # http://www.lucenetutorial.com/lucene-query-syntax.html
page = '0'  # <0-100>
sort = "relevance"  # newest, oldest
query_url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?" \
            f"q={query}" \
            f"&api-key={apikey}" \
            f"&begin_date={begin_date}" \
            f"&end_date={end_date}" \
            f"&fq={filter_query}" \
            f"&page={page}" \
            f"&sort={sort}"
r = requests.get(query_url)

# %%
print(r.json())
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'abstract': "Bush campaign officials can be heard daily on network of conservative-minded local radio shows in politically important states; goal is to prime grass roots faithful for battle next year; Bush's campaign strategists believe this network will give him edge in election that could go to whichever side best mobilizes its core voters; Democrats lack such a radio network of sympathetic listeners; strategists and radio experts say Bush campaign has taken use of radio to reach voters to new level of sophistication, using it far earlier in campaign cycle and appearing regularly on shows with even tiniest of audiences; survey by Talkers magazine, trade publication, found that nationwide, 73 percent of talk radio listeners registered to vote did so in 2000; Bush's campaign secretary Terry Holt says he calls in to radio shows nearly every day; notes that talk radio hosts let him address topics he wants to highlight, while hosts of national television programs would try to draw him into dogfight with Democratic candidates; photo (M)", 'web_url': 'https://www.nytimes.com/2003/12/29/us/the-2004-campaign-on-the-air-bush-s-campaign-finds-platform-on-local-radio.html', 'snippet': "Bush campaign officials can be heard daily on network of conservative-minded local radio shows in politically important states; goal is to prime grass roots faithful for battle next year; Bush's campaign strategists believe this network will give ...", 'lead_paragraph': "President Bush's campaign officials mostly avoid television programs like ''Hardball With Chris Matthews,'' ''Inside Politics'' or ''Face the Nation.''", 'print_section': 'A', 'print_page': '1', 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': "BUSH'S CAMPAIGN FINDS PLATFORM ON LOCAL RADIO", 'kicker': 'THE 2004 CAMPAIGN: ON THE AIR', 'content_kicker': None, 'print_headline': "THE 2004 CAMPAIGN: ON THE AIR; BUSH'S CAMPAIGN FINDS PLATFORM ON LOCAL RADIO", 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'organizations', 'value': 'Talkers', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Bush, George W', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'HOLT, TERRY', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Television', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Radio', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'ELECTION ISSUES', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'Presidential Election of 2004', 'rank': 7, 'major': 'N'}], 'pub_date': '2003-12-29T05:00:00+0000', 'document_type': 'article', 'news_desk': 'National Desk', 'section_name': 'U.S.', 'byline': {'original': 'By Jim Rutenberg', 'person': [{'firstname': 'Jim', 'middlename': None, 'lastname': 'Rutenberg', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'type_of_material': 'News', '_id': 'nyt://article/2ebf4d12-2dea-5b5d-bd06-d2016e3e4486', 'word_count': 1093, 'uri': 'nyt://article/2ebf4d12-2dea-5b5d-bd06-d2016e3e4486'}, {'abstract': "Pres Bush's campaign sees Howard Dean as likely Democratic candidate; settles on plan to portray him as reckless, angry and pessimistic, while framing 2004 election as referendum on direction of nation; Bush will set out upbeat themes and policy ideas, using State of the Union address as starting point; photo (M)", 'web_url': 'https://www.nytimes.com/2003/12/26/us/bush-advisers-with-eye-on-dean-formulate-04-plans.html', 'snippet': "Pres Bush's campaign sees Howard Dean as likely Democratic candidate; settles on plan to portray him as reckless, angry and pessimistic, while framing 2004 election as referendum on direction of nation; Bush will set out upbeat themes and policy i...", 'lead_paragraph': "President Bush's campaign has settled on a plan to run against Howard Dean that would portray him as reckless, angry an ...
